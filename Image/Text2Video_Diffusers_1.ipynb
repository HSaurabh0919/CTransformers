# %%
# !pip install diffusers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 32.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.6 MB/s eta 0:00:00
# ...
#   Created wheel for diffusers: filename=diffusers-0.21.2-py3-none-any.whl size=1489250 sha256=1bada9ae379db44286ac38b9a1ccc76a9151caa7f6a8ba3da68a47d31f17e73c
#   Stored in directory: /root/.cache/pip/wheels/2e/09/32/11c9e42c397d3f3494226b28ba68c4ad4718a68a65dba14ea6
# Successfully built diffusers
# ...

# %%
import torch
from diffusers import DiffusionPipeline
from diffusers.utils import export_to_video

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install transformers

# %%
# !pip3 install invisible_watermark transformers accelerate safetensors

# %%
pip install diffusers --upgrade

# %%
import torch
from diffusers import DiffusionPipeline
from diffusers.utils import export_to_video

pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b", torch_dtype=torch.float16, variant="fp16")
pipe.enable_model_cpu_offload()

# memory optimization
pipe.enable_vae_slicing()
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ...
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
prompt = "person running in hilly area with forest"
video_frames = pipe(prompt, num_frames=64).frames
video_path = export_to_video(video_frames)
video_path
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# '/tmp/tmpf1ky8x68.mp4'

# %%
video_path
# Out:
# '/tmp/tmpf1ky8x68.mp4'

# %%
import shutil

# Replace 'source_file.mp4' with the actual file name in your /tmp folder
source_file = video_path

# Replace '/content/drive/My Drive/' with the path where you want to save the file in Google Drive
destination_folder = '/content/drive/My Drive/videos/'

shutil.move(source_file, destination_folder)
# Out:
# '/content/drive/My Drive/videos/tmpf1ky8x68.mp4'
