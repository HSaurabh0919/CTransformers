# %%
# !pip install --upgrade diffusers  # make sure to use at least diffusers >= 0.22
# !pip install transformers accelerate

# %%
from diffusers import DiffusionPipeline
import torch

pipe = DiffusionPipeline.from_pretrained("SimianLuo/LCM_Dreamshaper_v7")

# To save GPU memory, torch.float16 can be used, but it may compromise image quality.
pipe.to(torch_device="cuda", torch_dtype=torch.float32)

# %%
prompt = "Self-portrait oil painting, a beautiful cyborg with golden hair, 8k"

# Can be set to 1~50 steps. LCM support fast inference even <= 4 steps. Recommend: 1~8 steps.
num_inference_steps = 4

images = pipe(prompt=prompt, num_inference_steps=num_inference_steps, guidance_scale=8.0, lcm_origin_steps=50, output_type="pil").images
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
prompt = "An artistic rendering of an underwater city enclosed in a transparent dome, with aquatic life thriving around it, symbolizing a future where humans live in harmony with marine ecosystems,8k"

# Can be set to 1~50 steps. LCM support fast inference even <= 4 steps. Recommend: 1~8 steps.
num_inference_steps = 25

images = pipe(prompt=prompt, num_inference_steps=num_inference_steps, guidance_scale=8.0, lcm_origin_steps=50, output_type="pil").images
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=768x768>

# %%
from PIL import Image
from google.colab import files
from google.colab import files

# Assuming img is your PIL Image
images[0].save("image_to_download.png")

# Now download it
files.download("image_to_download.png")
