# %%
# !pip install txtai

# %%
from txtai.embeddings import Embeddings

# Load the index from the HF Hub
embeddings = Embeddings()
embeddings.load(provider="huggingface-hub", container="neuml/txtai-wikipedia")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.98k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/534 [00:00<?, ?B/s]
# embeddings:   0%|          | 0.00/4.80G [00:00<?, ?B/s]
# documents:   0%|          | 0.00/3.24G [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# ...

# %%
# Run a search
embeddings.search("Roman Empire")
# Out:
# [{'id': 'Roman Empire',
#   'text': "The Roman Empire was the post-Republican state of ancient Rome and is generally understood to mean the period and territory ruled by the Romans following Octavian's assumption of sole rule under the Principate in 31 BC. It included territory in Europe, North Africa, and Western Asia, and was ruled by emperors. The fall of the Western Roman Empire in 476 conventionally marks the end of classical antiquity and the beginning of the Middle Ages.",
#   'score': 0.8845637440681458},
#  {'id': 'History of the Roman Empire',
# ...

# %%
# Run a search matching only the Top 1% of articles
embeddings.search("""
   SELECT id, text, score, percentile FROM txtai WHERE similar('Boston') AND
   percentile >= 0.99
""")
# Out:
# [{'id': 'Roxbury, Boston',
#   'text': 'Roxbury is a neighborhood within the City of Boston, Massachusetts, United States.',
#   'score': 0.8715406060218811,
#   'percentile': 0.992186165003909},
#  {'id': 'Boston',
#   'text': 'Boston, officially the City of Boston, is the capital and most populous city in the Commonwealth of Massachusetts, and is the cultural and financial center of New England in the Northeastern United States, with an area of  and a population of 675,647 in 2020. The Greater Boston metropolitan statistical area is the eleventh-largest in the country.',
#   'score': 0.871286153793335,
#   'percentile': 0.9998346622633546},
#  {'id': 'Boston, Lincolnshire',
#   'text': 'Boston is a market town and inland port in the borough of the same name in the county of Lincolnshire, England.',
#   'score': 0.8645882606506348,
#   'percentile': 0.9952779603424321}]

# %%
# Run a search matching only the Top 1% of articles
embeddings.search("""
   SELECT id, text, score, percentile FROM txtai WHERE similar('Boston') AND
   percentile >= 0.99
""")

# %%
# Run a search matching only the Top 1% of articles
embeddings.search("""
   SELECT id, text, score, percentile FROM txtai WHERE similar('GGUF') AND
   percentile >= 0.99
""")
# Out:
# [{'id': 'GeorgeNotFound',
#   'text': "George Davidson (born 1 November 1996), better known online as GeorgeNotFound (abbreviated as GNF; also known as Gogy), is an English internet personality, YouTuber, and Twitch streamer. He gained substantial popularity in 2020 and 2021 through uploading Minecraft content. Alongside content creator and frequent collaborator Dream, Davidson founded the Dream SMP, a Minecraft role-playing server consisting of multiple storylines and characters. As of July 2023, Davidson's five YouTube channels have all collectively reached over 15.2 million subscribers and over 742.1 million views.",
#   'score': 0.8348535299301147,
#   'percentile': 0.9921192062710793},
#  {'id': 'GlobalFoundries',
# ...

# %%
# Run a search
embeddings.search("peft")
# Out:
# [{'id': 'Seft',
#   'text': 'Seft is a village in Dastjerd Rural District, Khalajestan District, Qom County, Qom Province, Iran. At the 2005 census, its population was 67, in 25 families.',
#   'score': 0.8380155563354492},
#  {'id': 'Peak expiratory flow',
#   'text': "The peak expiratory flow (PEF), also called peak expiratory flow rate (PEFR) and peak flow measurement, is a person's maximum speed of expiration, as measured with a peak flow meter, a small, hand-held device used to monitor a person's ability to breathe out air. It measures the airflow through the bronchi and thus the degree of obstruction in the airways. Peak expiratory flow is typically measured in units of liters per minute (L/min).",
#   'score': 0.833933413028717},
#  {'id': 'Phosphatidylethanolamine N-methyltransferase',
# ...

# %%
# Run a search
embeddings.search("business rules")
# Out:
# [{'id': 'Business rules approach',
#   'text': 'Business rules are abstractions of the policies and practices of a business organization.  In computer software development, the business rules approach is a development methodology where rules are in a form that is used by, but does not have to be embedded in, business process management systems.',
#   'score': 0.9037003517150879},
#  {'id': 'Business rule',
# ...

# %% [markdown]
# Reference : https://huggingface.co/NeuML/txtai-wikipedia
