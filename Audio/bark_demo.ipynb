# %% [markdown]
# ## Install

# %%
# install bark (make sure you have torch>=2 for much faster flash-attention)
# !pip install git+https://github.com/suno-ai/bark.git
# Out:
# ...
#   Cloning https://github.com/suno-ai/bark.git to /tmp/pip-req-build-lkf76d8s
#   Running command git clone --filter=blob:none --quiet https://github.com/suno-ai/bark.git /tmp/pip-req-build-lkf76d8s
#   Resolved https://github.com/suno-ai/bark.git to commit 773624d26db84278a55aacae9a16d7b25fbccab8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 64.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 67.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 99.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Basics

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
from IPython.display import Audio

preload_models()
# Out:
# ...
# Downloading: "https://dl.fbaipublicfiles.com/encodec/v0/encodec_24khz-d7cc33bc.th" to /root/.cache/torch/hub/checkpoints/encodec_24khz-d7cc33bc.th
# 100%|██████████| 88.9M/88.9M [00:01<00:00, 92.2MB/s]

# %%
text_prompt = """
     Hello, my name is Suno. And, uh — and I like pizza. [laughs]
     But I also have other interests such as playing tic tac toe.
"""
audio_array = generate_audio(text_prompt)
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 28/28 [00:28<00:00,  1.02s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text_prompt = """Hanuman as a child, his innocent face glowing,
 holding the sun in his tender hands against a sunrise background, his tiny feet playing in the clouds."""
audio_array = generate_audio(text_prompt)
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 35/35 [00:30<00:00,  1.16it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text_prompt = """
    ♪ In the jungle, the mighty jungle, the lion barks tonight ♪
"""
audio_array = generate_audio(text_prompt,history_prompt='v2/en_speaker_9')
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 18/18 [00:18<00:00,  1.05s/it]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f61a94ff0c05> in <cell line: 5>()
#       3 """
#       4 audio_array = generate_audio(text_prompt,history_prompt='v2/en_speaker_9')
# ----> 5 v
#
# NameError: name 'v' is not defined

# %%
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text_prompt = """
    ♪ अच्चुतम केशवं कृष्ण दामोदरं,
राम नारायणं जानकी बल्लभम ।

कौन कहता हे भगवान आते नहीं,
तुम मीरा के जैसे बुलाते नहीं ।

अच्चुतम केशवं कृष्ण दामोदरं,
राम नारायणं जानकी बल्लभम ।♪
"""
audio_array = generate_audio(text_prompt,history_prompt='v2/hi_speaker_2')
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 34/34 [00:32<00:00,  1.03it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
hi_speaker_3
