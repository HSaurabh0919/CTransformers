# %% [markdown]
# Dataset : Banking77Classification : Single-domain intent detection dataset comprising 13,083 annotated examples over 77 intents.

# %%
import mteb
from sentence_transformers import SentenceTransformer

# Select model
model_name = "sentence-transformers/all-MiniLM-L6-v2"
model = mteb.get_model(model_name) # if the model is not implemented in MTEB it will be eq. to SentenceTransformer(model_name)

# Select tasks
tasks = mteb.get_tasks(tasks=["Banking77Classification.v2"])

# evaluate
results = mteb.evaluate(model, tasks=tasks)

# %%
results
# Out:
# ModelResult(model_name=sentence-transformers/all-MiniLM-L6-v2, model_revision=8b3219a92973c328a8e22fadcfa821b5dc75636a, task_results=[...](#1))

# %%
results.task_results[0].scores
# Out:
# {'test': [{'scores_per_experiment': [{'accuracy': 0.783485045513654,
#      'f1': np.float64(0.7729588412501014),
#      'f1_weighted': np.float64(0.7730648811718647),
#      'precision': np.float64(0.8005322122539135),
#      'precision_weighted': np.float64(0.8006052845063614),
#      'recall': np.float64(0.7833333333333333),
#      'recall_weighted': np.float64(0.783485045513654),
#      'ap': None,
#      'ap_weighted': None},
#     {'accuracy': 0.7929128738621587,
#      'f1': np.float64(0.7830051426673511),
#      'f1_weighted': np.float64(0.7831486416338619),
#      'precision': np.float64(0.8103950967341932),
#      'precision_weighted': np.float64(0.8103864486746206),
#      'recall': np.float64(0.7927156177156178),
#      'recall_weighted': np.float64(0.7929128738621587),
#      'ap': None,
#      'ap_weighted': None},
#     {'accuracy': 0.7994148244473342,
#      'f1': np.float64(0.7921012110389302),
#      'f1_weighted': np.float64(0.7922419913408779),
# ...

# %% [markdown]
# References :
#
# https://github.com/embeddings-benchmark/mteb?tab=readme-ov-file
